# %% [markdown]
# ##mpg 실습
# ####(K-digital AI) 박보현
# ####코랩을 사용함

# %% [markdown]
# #### [문제01]
# #### 자동차 배기량(displ)에 따라 고속도로 연비(hwy)가 다른지를 알아보자
# #### 배기량이 4 이하인 자동차화 5이상인 자동차 중 어떤 자동차의 고속도로연비가 평균적으로
# #### 높은지 알아보자

# %%
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-68202673-da18-449d-8247-5b5e56b1f632" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-68202673-da18-449d-8247-5b5e56b1f632">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving car_mpg.xlsx to car_mpg (1).xlsx

# %%
import io
import pandas as pd
import numpy as np
mpg = pd.read_excel(io.BytesIO(myfile['car_mpg.xlsx']))
mpg.head()
# Out:
#    Unnamed: 0 manufacturer model  displ  year  cyl       trans drv  cty  hwy  \
# 0           1         audi    a4    1.8  1999    4    auto(l5)   f   18   29
# 1           2         audi    a4    1.8  1999    4  manual(m5)   f   21   29
# 2           3         audi    a4    2.0  2008    4  manual(m6)   f   20   31
# 3           4         audi    a4    2.0  2008    4    auto(av)   f   21   30
# 4           5         audi    a4    2.8  1999    6    auto(l5)   f   16   26
#
#   fl    class
# 0  p  compact
# 1  p  compact
# 2  p  compact
# 3  p  compact
# 4  p  compact

# %%
mpg[(mpg['displ']<4)]['hwy'].mean()
# Out:
# 26.60810810810811

# %%
mpg[(mpg['displ']>5)]['hwy'].mean()
# Out:
# 18.13888888888889

# %% [markdown]
# ####[문제02]
# #### 자동차 제조 회사에 따라 도시 연비가 다른지 알아보려고 한다.
# #### audi와 toyota 중 어느 manufacturer(자동차 제조 회사)의 cty(도시연비)가 평균적으로 더 높은지 알아보시오.

# %%
mpg[mpg['manufacturer']=='audi']['cty'].mean()
# Out:
# 17.61111111111111

# %%
mpg[mpg['manufacturer']=='toyota']['cty'].mean()
# Out:
# 18.529411764705884

# %% [markdown]
# ####[문제03]
# #### chevrolet, ford, honda 자동차의 고속도로 연비 평균을 알아보려고 한다.
# #### 이 회사들의 데이터를 추출한 후 hwy 전체 평균을 확인하시오.

# %%
mpg[mpg['manufacturer']=='chevrolet']['hwy'].mean()
# Out:
# 21.894736842105264

# %%
mpg[mpg['manufacturer']=='ford']['hwy'].mean()
# Out:
# 19.36

# %%
mpg[mpg['manufacturer']=='honda']['hwy'].mean()
# Out:
# 32.55555555555556

# %% [markdown]
# ####[문제04]
# #### print('연료가격 변수 추가(price_fl) - ')
# #### print('c : 가스 2.35 , d : 디젤 2.38 , e : 에탄올 2.11 , p : 고급휘발유 2.76, r : 보통휘발유 2.22')

# %%
mpg["price_fl"] = np.nan
mpg
# Out:
#      Unnamed: 0 manufacturer   model  displ  year  cyl       trans drv  cty  \
# 0             1         audi      a4    1.8  1999    4    auto(l5)   f   18
# 1             2         audi      a4    1.8  1999    4  manual(m5)   f   21
# 2             3         audi      a4    2.0  2008    4  manual(m6)   f   20
# 3             4         audi      a4    2.0  2008    4    auto(av)   f   21
# 4             5         audi      a4    2.8  1999    6    auto(l5)   f   16
# ..          ...          ...     ...    ...   ...  ...         ...  ..  ...
# 229         230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19
# 230         231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21
# 231         232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16
# 232         233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18
# 233         234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17
#
#      hwy fl    class  price_fl
# ...

# %%
mpg['price_fl'] = np.where(mpg['fl'] == 'c', '가스 2.35', mpg['price_fl'])
mpg['price_fl'] = np.where(mpg['fl'] == 'd', '디젤 2.38', mpg['price_fl'])
mpg['price_fl'] = np.where(mpg['fl'] == 'e', '에탄올 2.11', mpg['price_fl'])
mpg['price_fl'] = np.where(mpg['fl'] == 'p', '고급휘발유 2.76', mpg['price_fl'])
mpg['price_fl'] = np.where(mpg['fl'] == 'r', '보통휘발유 2.22', mpg['price_fl'])
mpg
# Out:
#      Unnamed: 0 manufacturer   model  displ  year  cyl       trans drv  cty  \
# 0             1         audi      a4    1.8  1999    4    auto(l5)   f   18
# 1             2         audi      a4    1.8  1999    4  manual(m5)   f   21
# 2             3         audi      a4    2.0  2008    4  manual(m6)   f   20
# 3             4         audi      a4    2.0  2008    4    auto(av)   f   21
# 4             5         audi      a4    2.8  1999    6    auto(l5)   f   16
# ..          ...          ...     ...    ...   ...  ...         ...  ..  ...
# 229         230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19
# 230         231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21
# 231         232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16
# 232         233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18
# 233         234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17
#
#      hwy fl    class    price_fl
# ...

# %% [markdown]
# #### [문제 05]
# #### print('병합한 프레임에서 model , fl, price_fl 추출한다면? - ')

# %%
new = mpg[['model', 'fl', 'price_fl']]
new
# Out:
#       model fl    price_fl
# 0        a4  p  고급휘발유 2.76
# 1        a4  p  고급휘발유 2.76
# 2        a4  p  고급휘발유 2.76
# 3        a4  p  고급휘발유 2.76
# 4        a4  p  고급휘발유 2.76
# ..      ... ..         ...
# 229  passat  p  고급휘발유 2.76
# 230  passat  p  고급휘발유 2.76
# 231  passat  p  고급휘발유 2.76
# 232  passat  p  고급휘발유 2.76
# 233  passat  p  고급휘발유 2.76
#
# [234 rows x 3 columns]

# %% [markdown]
# #### [문제 06]
# #### 데이터 전처리 과정에서 결측값 확인하기

# %%
from pandas import DataFrame

# %%
# null값이 있으면 True
pd.isnull(mpg)
# Out:
#      Unnamed: 0  manufacturer  model  displ   year    cyl  trans    drv  \
# 0         False         False  False  False  False  False  False  False
# 1         False         False  False  False  False  False  False  False
# 2         False         False  False  False  False  False  False  False
# 3         False         False  False  False  False  False  False  False
# 4         False         False  False  False  False  False  False  False
# ..          ...           ...    ...    ...    ...    ...    ...    ...
# 229       False         False  False  False  False  False  False  False
# 230       False         False  False  False  False  False  False  False
# 231       False         False  False  False  False  False  False  False
# 232       False         False  False  False  False  False  False  False
# 233       False         False  False  False  False  False  False  False
#
#        cty    hwy     fl  class  price_fl
# 0    False  False  False  False     False
# ...

# %% [markdown]
# #### [문제 07]
# #### 구동방식(drv) 별 고속도로 연비(hwy)평균
# #### 임의적으로 결측값 처리를 위해서 더미 값을 넣어보도록 하자
# #### 데이터 전처리 과정에서 결측값 확인하기

# %%
mpg.groupby('drv').mean()
# Out:
#      Unnamed: 0     displ         year       cyl        cty        hwy
# drv
# 4    105.660194  3.998058  2003.718447  6.485437  14.330097  19.174757
# f    140.433962  2.558491  2003.160377  4.886792  19.971698  28.160377
# r     69.040000  5.176000  2004.040000  7.680000  14.080000  21.000000

# %% [markdown]
# #### [문제 08]
# #### hwy변수의 결측값을 제외하고, 어떤 구동방식의 고속도로평균 연비가 높은지 알아보자

# %%
mpg.dropna(subset=['hwy'])
data2 = mpg.groupby('drv').mean()
data3 = data2.loc[:, ['hwy']]
data3
# Out:
#            hwy
# drv
# 4    19.174757
# f    28.160377
# r    21.000000

# %% [markdown]
# #### [문제 09]
# #### 구동방식별 연비평균을 비교하기 위한 막대 그래프로 시각화 해 보자

# %%
# 시각화
import matplotlib.pyplot as plt 
# %matplotlib inline


import json 

import warnings
warnings.filterwarnings(action='ignore')

from datetime import date, datetime, timedelta
from dateutil.parser import parse

# %%
# 한글 폰트 문제 해결
import platform

from matplotlib import font_manager, rc

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~') 


# 차트 축 <- 음수 부호 지원
import matplotlib
matplotlib.rcParams['axes.unicode_minus'] = False
# Out:
# Unknown system... sorry~~~~

# %%
data3.plot(kind = 'bar', figsize = (10, 10))
plt.show()
